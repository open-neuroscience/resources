# %%
import pandas as pd
import os

# %%
rootPath = "/home/andre/repositories/openneuroscience/open-neuroscience.github.io/content/en/post/"
folders = os.listdir(rootPath)
for item in folders:
    try:
        with open(rootPath+item+"/index.md") as file:
            dummie = file.readlines()
    except NotADirectoryError:
        pass
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-27-1e76c94bc8af> in <module>
#       3 for item in folders:
#       4     try:
# ----> 5         with open(rootPath+item+"/index.md") as file:
#       6             dummie = file.readlines()
#       7     except NotADirectoryError:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/andre/repositories/openneuroscience/open-neuroscience.github.io/content/en/post/Self_Organizing_Recurrent_Neural_Networks/index.md'

# %%
dummie[1:].index("---\n")
# Out:
# 6

# %%
dummie
# Out:
# ['---\n',
#  'title: MNE-Python\n',
#  'date: 2020-07-12\n',
#  "authors: ['admin']\n",
#  'layout: post\n',
#  "categories: ['Software','Data Analysis','Human electrophysiology','Human Neuroscience']\n",
#  "tags: ['Software','Data Analysis','Human electrophysiology','Human Neuroscience']\n",
#  '---\n',
# ...

# %%
title = "title:?" in dummie

# %%
title
# Out:
# False
