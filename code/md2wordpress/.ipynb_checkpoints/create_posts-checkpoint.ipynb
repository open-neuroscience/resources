# %%
#import needed libraries
import pandas as pd
import json
import numpy as np
import requests
from datetime import datetime
from wordpress_xmlrpc import Client, WordPressPost
from wordpress_xmlrpc.methods.posts import NewPost
from wordpress_xmlrpc.methods import media, posts, taxonomies
from wordpress_xmlrpc.compat import xmlrpc_client
from wordpress_xmlrpc import WordPressTerm

import time
import copy
import py2wp

#from wordpress_xmlrpc import Client, WordPressPost
#from wordpress_xmlrpc.methods.posts import GetPosts, NewPost
#from wordpress_xmlrpc.methods.users import GetUserInfo

# %%
# create connection to website, download the project post template and make a copy

# website_name.txt is a file that contains username and password to access the website. This is put as gitignore, so that 
# this sensitive information is not shared openly accross the web
with open("website_credentials.txt") as fid:
    username = fid.readline()
    password = fid.readline()
    

websiteName = "https://open-neuroscience-60fc93.ingress-baronn.easywp.com"
url = websiteName+"/xmlrpc.php"


wp = Client(url, username, password)


#get template post for projects:
allProjects = wp.call(posts.GetPosts({"post_type": "project"}))
for item in allProjects:
    if item.title=="project template2":
        template=item
time.sleep(30)
print ("done")
# Out:
# done

# %%
#google sheet information
with open("sheet_id.txt") as fid:
    sheetId = fid.readline()
    

#pull data from the sheet into a pandas dataframe
allPosts = pd.read_csv('https://docs.google.com/spreadsheets/d/' + 
                   sheetId +
                   '/export?format=csv',
                   # Set first column as rownames in data frame
                   index_col=0,
                  )

# %%
import py2wp


wpTags = wp.call(taxonomies.GetTerms('ontag'))
#run a loop to go through all post entries and create posts as needed
for index in allPosts.index:
    #if index ==3 and allPosts[allPosts.index==index]["posted"][index]!=True:
    if allPosts[allPosts.index==index]["posted"][index]!=True:
        print("start post ... ")
        entry = allPosts[allPosts.index==index]
        #print(index)
        
        createdDate = entry["Marca temporal"][index]            
        title = entry["Project Title"][index]
        projectVideoURL = entry["Link to video for your project"][index]
        projectImageURL = entry["Link to raw image of your project"][index]
        summary = entry["Description of the project"][index]
        projectAuthor = entry["Project Author"][index]
        projectURL = entry["Link to Project Website or GitHub repository"][index]
        postCreator = entry["Post Author"][index]
        entryTags = list()

        for i in range(4):
            tagTemp = entry["Project categories (please select at most one per row) [Category {number}]".format(number=i+1)]
            #print(type(tagTemp.values[0]))
            if type(tagTemp.values[0]) is not float:
                for wpEntry in wpTags:
                    if wpEntry.name == tagTemp.values[0].lower():
                        entryTags.append(wpEntry)
                #postTags.append("<WordPressTerm: b'term'>".format(term=tagTemp.values[0]))
                #entryTags.append(tagTemp.values[0])
        
        #postTags = list()
        #for item in entryTags:
            #if item=="Software":
                #tag = WordPressTerm()
                #tag.taxonomy = 'post_tag'
                #tag.name = item
                #postTags.append(tag)
                #del(tag)
        #tag = WordPressTerm()
        #tag.taxonomy = 'post_tag'
        #tag.name = item
        #postTags = tag
        #'terms': [<WordPressTerm: b'neuroscience'>, <WordPressTerm: b'open source'>],
        #newPost.date = datetime.strptime(creationDate, '%Y-%m-%d %H:%M:%S')
        
        #create content
        postString = sumText = py2wp.summary(summaryText=summary)+\
            py2wp.spacer()+\
            py2wp.author(authorText=projectAuthor)+\
            py2wp.spacer()+\
            py2wp.project_links(projectURL,projectURL)+\
            py2wp.spacer()


        #acheck all uploaded media
        allMedia = wp.call(media.GetMediaLibrary({"parent_id":""}))
        
        #download media
        imageName = title.replace(" ","_")
        imageName,iFormat = py2wp.download_url_image(projectImageURL,imageName = imageName.lower())
        print("imagename "+imageName)
        imageFlag = 0
        for item in allMedia:
            #print(item.title)
            if item.title == imageName:
                imageFlag = 1
                image = item
                print("image already uploaded")

        if imageFlag == 1:
            imageID = image.id
            imageTitle = image.title
            imageLink = image.link
        else:
            response = py2wp.upload_image_wp(imageName,iFormat,wp)
            imageID = response["id"]
            imageTitle = response["title"]
            imageLink = response["link"]
        #replace video URL
        if type(projectVideoURL) is not float:
            postString = postString+ py2wp.embed_video(projectVideoURL)+py2wp.spacer()

        postString = postString+py2wp.post_creator(creatorText = postCreator)+py2wp.spacer()
        newPost = copy.deepcopy(template)
        newPost.title = title
        newPost.content = postString
        newPost.thumbnail = imageID
        newPost.date = datetime.strptime(createdDate, '%Y-%m-%d %H:%M:%S')
        newPost.author = "python-bot"
        newPost.slug = title
        newPost.terms = entryTags
        newPost.id = wp.call(posts.NewPost(newPost))

        #del(newPost)
        print("ready to wait")
        time.sleep(60)    
        print("done")
# Out:
# start post ...
# image type: image/png
# imagename 3d_slicer.png
# image already uploaded
# ready to wait
# done

# %%
vars(newPost)

# %%
#len(tags = wp.call(taxonomies.GetTerms('post_tag')))
vars(tags[0])
# Out:
# {'_def': {'id': <wordpress_xmlrpc.fieldmaps.FieldMap at 0x1ceceafcd00>,
#   'group': <wordpress_xmlrpc.fieldmaps.FieldMap at 0x1ceceafcd30>,
#   'taxonomy': <wordpress_xmlrpc.fieldmaps.FieldMap at 0x1ceceafc3a0>,
#   'taxonomy_id': <wordpress_xmlrpc.fieldmaps.FieldMap at 0x1ced16b6760>,
#   'name': <wordpress_xmlrpc.fieldmaps.FieldMap at 0x1ced0fd8640>,
#   'slug': <wordpress_xmlrpc.fieldmaps.FieldMap at 0x1ced16b63d0>,
#   'description': <wordpress_xmlrpc.fieldmaps.FieldMap at 0x1ced16b64f0>,
#   'parent': <wordpress_xmlrpc.fieldmaps.FieldMap at 0x1ced16b6400>,
#   'count': <wordpress_xmlrpc.fieldmaps.IntegerFieldMap at 0x1ced0fd8850>},
#  'id': '32',
#  'group': '0',
#  'taxonomy': 'post_tag',
#  'taxonomy_id': '32',
#  'name': 'Behaviour',
#  'slug': 'behaviour',
#  'description': '',
#  'parent': '0',
#  'count': 0}

# %%
#google sheet information
with open("sheet_id.txt") as fid:
    sheetId = fid.readline()
    

#pull data from the sheet into a pandas dataframe
allPosts = pd.read_csv('https://docs.google.com/spreadsheets/d/' + 
                   sheetId +
                   '/export?format=csv',
                   # Set first column as rownames in data frame
                   index_col=0,
                  )


#run a loop to go through all post entries and create posts as needed
for index in allPosts.index:
    if index ==1:
        
        newPost = copy.deepcopy(template)
        
        entry = allPosts[allPosts.index==index]
        print(index)
        if entry["posted"][index]!=True:
            


                
                
            entryCreateData = entry["Marca temporal"][index]            
            title = entry["Project Title"][index]
            #title to be recognized in wordpress
            newPost.title = title
            #URL for wordpress
            newPost.slug = title
            # creation date
            creationDate = entry["Marca temporal"][index]
            newPost.date = datetime.strptime(creationDate, '%Y-%m-%d %H:%M:%S')

            
            #projectImageURL = entry["Link to raw image of your project"][index]
            
            #oldImageURL = 'https://open-neuroscience-60fc93.ingress-baronn.easywp.com/wp-content/uploads/2022/02/openneuroscience_blue_1600by400_border-1024x232.png'
            
            #imageName,iFormat = py2wp.download_url_image(projectImageURL,imageName = title.lower())
            #print("imagename "+imageName)
            #if imageName != "logo_blue.png":
            #    response = py2wp.upload_image_wp(imageName,iFormat,wp)
            #    time.sleep(2)
            #else:
                
            #    response = {"id":419,"link":oldImageURL}
            #print("image uploaded link: " +str(response["link"]))
            
            time.sleep(2)
            
            #attachmentId = response['id']
            #newPost.thumbnail = attachmentId
            
            postContent = replace_text(stringIn = postContent,
                                       oldText = '<img src='+oldImageURL,
                                       newText = '<img src='+response["link"])
            
            postContent = replace_text(stringIn = postContent,
                                       oldText = 'wp-image-419',
                                       newText = 'wp-image-'+str(response["id"]))
            
            
            #replace summary
            summary = entry["Description of the project"][index]
            print(summary)
            postContent = replace_text(stringIn = postContent,
                                       oldText = '<p class="has-medium-font-size">Project Summary</p>',
                                       newText = '<p class="has-medium-font-size">'+summary+'</p>')
            
            #replace project author
            projectAuthor = entry["Project Author"][index]
            postContent = replace_text(stringIn = postContent,
                                       oldText = '<p class="has-medium-font-size">Project Authors</p>', 
                                       newText = '<p class="has-medium-font-size">'+projectAuthor+'</p>')
            
            
            
            
            projectAuthorTwitter = entry["Project Author Twitter handle"][index]
            if type(projectAuthorTwitter) is not float:
                pass
            
            
            
            
            # replace project URL
            projectURL = entry["Link to Project Website or GitHub repository"][index]
            postContent = replace_text(stringIn = postContent,
                                       oldText = '<a href="hyperlink">', 
                                       newText = '<a href="'+projectURL+'">')
            
            
            postContent = replace_text(stringIn = postContent,
                                       oldText = " hyperlink1</a>", 
                                       newText = projectURL+"</a>")
            
            
            
            #replace video URL
            projectVideoURL = entry["Link to video for your project"][index]
            if type(projectVideoURL) is not float:
                postContent = replace_text(stringIn = postContent,
                                           oldText = 'https://www.youtube.com/watch?v=82Vhe9iPVQc',
                                           newText = projectVideoURL)
                
                postContent = replace_text(stringIn = postContent,
                                           oldText = 'https://www.youtube.com/watch?v=82Vhe9iPVQc', 
                                           newText = projectVideoURL)
            else:
                pass
                 #postContent = replace_text(stringIn = postContent,
                 #                          oldText = '<!-- wp:group --> \
                 #                           <div class="wp-block-group"><!-- wp:heading {"level":3} -->\
                 #                           <h3 id="video">video</h3>\
                 #                           <!-- /wp:heading -->\
                 #                           <!-- wp:embed /--></div>\
                 #                           <!-- /wp:group -->\
                 #                           <!-- wp:spacer {"height":45} -->\
                 #                           <div style="height:45px" aria-hidden="true" class="wp-block-spacer"></div>\
                 #                           <!-- /wp:spacer -->',
                 #                          newText = '')
            
            
            
            entryAuthor = entry["Post Author"][index]
            postContent = replace_text(stringIn = postContent,
                                       oldText = '<p class="has-medium-font-size">post submitter</p>', 
                                       newText = '<p>'+entryAuthor+'</p>')
            
            #tags
            newPost.tags = entry["tags"][index]
            
            category1 = entry["Project categories (please select at most one per row) [Category 1]"][index]
            category2 = entry["Project categories (please select at most one per row) [Category 2]"][index]
            category3 = entry["Project categories (please select at most one per row) [Category 3]"][index]
            category4 = entry["Project categories (please select at most one per row) [Category 4]"][index]

            newPost.content = postContent
            newPost.author = "python-bot"
            #print(newPost.content)
            newPost.id = wp.call(posts.NewPost(newPost))
            del(newPost)
            time.sleep(1)
# Out:
# 1.0
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-522e9e8c3d2b> in <module>
#      59             #newPost.thumbnail = attachmentId
#      60
# ---> 61             postContent = replace_text(stringIn = postContent,
#      62                                        oldText = '<img src='+oldImageURL,
#      63                                        newText = '<img src='+response["link"])
#
# NameError: name 'replace_text' is not defined

# %%
#vars(template)

template.thumbnail
test = template.thumbnail
for key in test.keys():
    pass

test["link"]=
test
# Out:
# {'attachment_id': 420,
#  'date_created_gmt': <DateTime '20220211T12:39:33' at 0x7f10bf2a94f0>,
#  'parent': 0,
#  'link': 'https://open-neuroscience-60fc93.ingress-baronn.easywp.com/wp-content/uploads/2022/02/openneuroscience_blue_1600by400_border.png',
#  'title': 'openneuroscience_blue_1600by400_border',
#  'caption': '',
#  'description': '',
#  'metadata': {'width': 1600,
#   'height': 362,
#   'file': '2022/02/openneuroscience_blue_1600by400_border.png',
#   'sizes': {'medium': {'file': 'openneuroscience_blue_1600by400_border-300x68.png',
#     'width': 300,
#     'height': 68,
#     'mime-type': 'image/png'},
#    'large': {'file': 'openneuroscience_blue_1600by400_border-1024x232.png',
#     'width': 1024,
#     'height': 232,
#     'mime-type': 'image/png'},
#    'thumbnail': {'file': 'openneuroscience_blue_1600by400_border-150x150.png',
#     'width': 150,
#     'height': 150,
#     'mime-type': 'image/png'},
#    'medium_large': {'file': 'openneuroscience_blue_1600by400_border-768x174.png',
#     'width': 768,
#     'height': 174,
#     'mime-type': 'image/png'},
#    '1536x1536': {'file': 'openneuroscience_blue_1600by400_border-1536x348.png',
#     'width': 1536,
#     'height': 348,
#     'mime-type': 'image/png'},
#    'neve-blog': {'file': 'openneuroscience_blue_1600by400_border-930x362.png',
#     'width': 930,
#     'height': 362,
#     'mime-type': 'image/png'}},
#   'image_meta': {'aperture': '0',
#    'credit': '',
#    'camera': '',
#    'caption': '',
#    'created_timestamp': '0',
#    'copyright': '',
#    'focal_length': '0',
#    'iso': '0',
#    'shutter_speed': '0',
#    'title': '',
#    'orientation': '0',
#    'keywords': []}},
#  'type': 'image/png',
#  'thumbnail': 'https://open-neuroscience-60fc93.ingress-baronn.easywp.com/wp-content/uploads/2022/02/openneuroscience_blue_1600by400_border-150x150.png'}

# %%
print(postString)
# Out:
# <!-- wp:group -->
# <div class="wp-block-group"><!-- wp:heading {"level":3} -->
# <h3 id="summary">Summary</h3>
# <!-- /wp:heading -->
#
# <!-- wp:paragraph {"fontSize":"medium"} -->
# <p class="has-medium-font-size">lorem ipsum</p>
# <!-- /wp:paragraph --></div>
# <!-- /wp:group -->
# <!-- wp:spacer {"height":45} -->
# <div style="height:45px" aria-hidden="true" class="wp-block-spacer"></div>
# <!-- /wp:spacer -->
#
# <!-- wp:group -->
# <div class="wp-block-group"><!-- wp:heading {"level":3} -->
# <h3 id="authors">Authors</h3>
# <!-- /wp:heading -->
#
# <!-- wp:paragraph {"fontSize":"medium"} -->
# <p class="has-medium-font-size">Charles Darwin</p>
# <!-- /wp:paragraph --></div>
# <!-- /wp:group -->
# <!-- wp:spacer {"height":45} -->
# <div style="height:45px" aria-hidden="true" class="wp-block-spacer"></div>
# <!-- /wp:spacer -->
#
# <!-- wp:group -->
# <div class="wp-block-group"><!-- wp:heading {"level":3} -->
# <h3 id="links">links</h3>
# <!-- /wp:heading -->
#
# <!-- wp:html -->
# <a href="https:open-neuroscience.com"> OpenNeuro</a>
# <!-- /wp:html --></div>
# <!-- /wp:group -->
# <!-- wp:spacer {"height":45} -->
# <div style="height:45px" aria-hidden="true" class="wp-block-spacer"></div>
# <!-- /wp:spacer -->
#
# <!-- wp:group -->
# <div class="wp-block-group"><!-- wp:heading {"level":3} -->
# <h3 id="generated-by">This post was created by:</h3>
# <!-- /wp:heading -->
# <!-- wp:paragraph {"fontSize":"medium"} -->
# <p class="has-medium-font-size">charles Darwin</p>
# <!-- /wp:paragraph --></div>
# <!-- /wp:group -->
# <!-- wp:spacer {"height":45} -->
# <div style="height:45px" aria-hidden="true" class="wp-block-spacer"></div>
# <!-- /wp:spacer -->

# %%
vars(template[0])
# Out:
# {'_def': {'id': <wordpress_xmlrpc.fieldmaps.FieldMap at 0x7fb18429b160>,
#   'user': <wordpress_xmlrpc.fieldmaps.FieldMap at 0x7fb18429b100>,
#   'date': <wordpress_xmlrpc.fieldmaps.DateTimeFieldMap at 0x7fb1558fd880>,
#   'date_modified': <wordpress_xmlrpc.fieldmaps.DateTimeFieldMap at 0x7fb1558fd910>,
#   'slug': <wordpress_xmlrpc.fieldmaps.FieldMap at 0x7fb154a70280>,
#   'post_status': <wordpress_xmlrpc.fieldmaps.FieldMap at 0x7fb154a70610>,
#   'title': <wordpress_xmlrpc.fieldmaps.FieldMap at 0x7fb1558fd970>,
#   'content': <wordpress_xmlrpc.fieldmaps.FieldMap at 0x7fb154a702b0>,
#   'excerpt': <wordpress_xmlrpc.fieldmaps.FieldMap at 0x7fb154a70f10>,
#   'link': <wordpress_xmlrpc.fieldmaps.FieldMap at 0x7fb1549eebe0>,
#   'comment_status': <wordpress_xmlrpc.fieldmaps.FieldMap at 0x7fb1549eed90>,
#   'ping_status': <wordpress_xmlrpc.fieldmaps.FieldMap at 0x7fb1549ee820>,
#   'terms': <wordpress_xmlrpc.fieldmaps.TermsListFieldMap at 0x7fb1558fd9d0>,
#   'terms_names': <wordpress_xmlrpc.fieldmaps.FieldMap at 0x7fb1549eefd0>,
#   'custom_fields': <wordpress_xmlrpc.fieldmaps.FieldMap at 0x7fb1549eee20>,
#   'enclosure': <wordpress_xmlrpc.fieldmaps.FieldMap at 0x7fb1549eee80>,
#   'password': <wordpress_xmlrpc.fieldmaps.FieldMap at 0x7fb1549ee7c0>,
#   'post_format': <wordpress_xmlrpc.fieldmaps.FieldMap at 0x7fb1549fbdf0>,
#   'thumbnail': <wordpress_xmlrpc.fieldmaps.FieldMap at 0x7fb1549fb070>,
#   'sticky': <wordpress_xmlrpc.fieldmaps.FieldMap at 0x7fb1549fb0d0>,
#   'post_type': <wordpress_xmlrpc.fieldmaps.FieldMap at 0x7fb1558fda30>,
#   'parent_id': <wordpress_xmlrpc.fieldmaps.FieldMap at 0x7fb1549fb130>,
#   'menu_order': <wordpress_xmlrpc.fieldmaps.IntegerFieldMap at 0x7fb1558fda90>,
#   'guid': <wordpress_xmlrpc.fieldmaps.FieldMap at 0x7fb1549fb1c0>,
#   'mime_type': <wordpress_xmlrpc.fieldmaps.FieldMap at 0x7fb1549fb220>},
#  'id': '421',
#  'user': '1',
#  'date': datetime.datetime(2022, 2, 11, 12, 45, 48),
#  'date_modified': datetime.datetime(2022, 2, 13, 22, 20, 46),
#  'slug': 'project-template2',
#  'post_status': 'publish',
#  'title': 'project template2',
#  'content': '<!-- wp:html -->\n<div align="right">\n<a href="https://twitter.com/openneurosci?ref_src=twsrc%5Etfw" class="twitter-follow-button" data-show-count="false">Follow @openneurosci</a><script async="" src="https://platform.twitter.com/widgets.js" charset="utf-8"></script>\n</div>\n<!-- /wp:html -->\n\n<!-- wp:image {"align":"center","id":419,"width":512,"height":116,"sizeSlug":"large","linkDestination":"none"} -->\n<div class="wp-block-image"><figure class="aligncenter size-large is-resized"><img src="https://open-neuroscience-60fc93.ingress-baronn.easywp.com/wp-content/uploads/2022/02/openneuroscience_blue_1600by400_border-1024x232.png" alt="" class="wp-image-419" width="512" height="116"/></figure></div>\n<!-- /wp:image -->\n\n<!-- wp:group -->\n<div class="wp-block-group"><!-- wp:heading {"level":3} -->\n<h3 id="summary">Summary</h3>\n<!-- /wp:heading -->\n\n<!-- wp:paragraph {"fontSize":"medium"} -->\n<p class="has-medium-font-size">Project Summary</p>\n<!-- /wp:paragraph --></div>\n<!-- /wp:group -->\n\n<!-- wp:group -->\n<div class="wp-block-group"><!-- wp:heading {"level":3} -->\n<h3 id="authors">Authors</h3>\n<!-- /wp:heading -->\n\n<!-- wp:paragraph {"fontSize":"medium"} -->\n<p class="has-medium-font-size">Project Authors</p>\n<!-- /wp:paragraph --></div>\n<!-- /wp:group -->\n\n<!-- wp:group -->\n<div class="wp-block-group"><!-- wp:heading {"level":3} -->\n<h3 id="links">links</h3>\n<!-- /wp:heading -->\n\n<!-- wp:html -->\n<a href="hyperlink"> hyperlink1</a>\n<!-- /wp:html --></div>\n<!-- /wp:group -->\n\n<!-- wp:group -->\n<div class="wp-block-group"><!-- wp:heading {"level":3} -->\n<h3 id="video">video</h3>\n<!-- /wp:heading -->\n\n<!-- wp:embed {"url":"https://www.youtube.com/watch?v=82Vhe9iPVQc","type":"video","providerNameSlug":"youtube","responsive":true,"className":"wp-embed-aspect-16-9 wp-has-aspect-ratio"} -->\n<figure class="wp-block-embed is-type-video is-provider-youtube wp-block-embed-youtube wp-embed-aspect-16-9 wp-has-aspect-ratio"><div class="wp-block-embed__wrapper">\nhttps://www.youtube.com/watch?v=82Vhe9iPVQc\n</div></figure>\n<!-- /wp:embed --></div>\n<!-- /wp:group -->\n\n<!-- wp:group -->\n<div class="wp-block-group"><!-- wp:heading {"level":3} -->\n<h3 id="generated-by">This post was created by:</h3>\n<!-- /wp:heading -->\n\n<!-- wp:paragraph {"fontSize":"medium"} -->\n<p class="has-medium-font-size">post submitter</p>\n<!-- /wp:paragraph --></div>\n<!-- /wp:group -->\n\n<!-- wp:paragraph -->\n<p></p>\n<!-- /wp:paragraph -->',
#  'excerpt': '',
#  'link': 'https://open-neuroscience-60fc93.ingress-baronn.easywp.com/project/project-template2/',
#  'comment_status': 'open',
#  'ping_status': 'closed',
#  'terms': [],
#  'custom_fields': [],
#  'password': '',
#  'post_format': 'standard',
#  'thumbnail': [],
#  'sticky': False,
#  'post_type': 'project',
#  'parent_id': '0',
#  'menu_order': 0,
#  'guid': 'https://open-neuroscience-60fc93.ingress-baronn.easywp.com/?post_type=project&#038;p=421',
#  'mime_type': ''}

# %%
vars(newPost)
# Out:
# {'_def': {'id': <wordpress_xmlrpc.fieldmaps.FieldMap at 0x7fde9a56c910>,
#   'user': <wordpress_xmlrpc.fieldmaps.FieldMap at 0x7fde9a56c610>,
#   'date': <wordpress_xmlrpc.fieldmaps.DateTimeFieldMap at 0x7fde9a56c580>,
#   'date_modified': <wordpress_xmlrpc.fieldmaps.DateTimeFieldMap at 0x7fde9a56c520>,
#   'slug': <wordpress_xmlrpc.fieldmaps.FieldMap at 0x7fde9a56c250>,
#   'post_status': <wordpress_xmlrpc.fieldmaps.FieldMap at 0x7fde9a617520>,
#   'title': <wordpress_xmlrpc.fieldmaps.FieldMap at 0x7fde9a502bb0>,
#   'content': <wordpress_xmlrpc.fieldmaps.FieldMap at 0x7fde9a502ac0>,
#   'excerpt': <wordpress_xmlrpc.fieldmaps.FieldMap at 0x7fde9a502670>,
#   'link': <wordpress_xmlrpc.fieldmaps.FieldMap at 0x7fde9a5026a0>,
#   'comment_status': <wordpress_xmlrpc.fieldmaps.FieldMap at 0x7fdec873baf0>,
#   'ping_status': <wordpress_xmlrpc.fieldmaps.FieldMap at 0x7fde9a522a30>,
#   'terms': <wordpress_xmlrpc.fieldmaps.TermsListFieldMap at 0x7fde9a522820>,
#   'terms_names': <wordpress_xmlrpc.fieldmaps.FieldMap at 0x7fde9a522ee0>,
#   'custom_fields': <wordpress_xmlrpc.fieldmaps.FieldMap at 0x7fde9a522250>,
#   'enclosure': <wordpress_xmlrpc.fieldmaps.FieldMap at 0x7fde9a522880>,
#   'password': <wordpress_xmlrpc.fieldmaps.FieldMap at 0x7fde9a522940>,
#   'post_format': <wordpress_xmlrpc.fieldmaps.FieldMap at 0x7fde9a522970>,
#   'thumbnail': <wordpress_xmlrpc.fieldmaps.FieldMap at 0x7fde9a522d60>,
#   'sticky': <wordpress_xmlrpc.fieldmaps.FieldMap at 0x7fde9a5228b0>,
#   'post_type': <wordpress_xmlrpc.fieldmaps.FieldMap at 0x7fde9a522190>,
#   'parent_id': <wordpress_xmlrpc.fieldmaps.FieldMap at 0x7fde9a522be0>,
#   'menu_order': <wordpress_xmlrpc.fieldmaps.IntegerFieldMap at 0x7fde9a4ba100>,
#   'guid': <wordpress_xmlrpc.fieldmaps.FieldMap at 0x7fde9a4ba250>,
#   'mime_type': <wordpress_xmlrpc.fieldmaps.FieldMap at 0x7fde9a4ba190>},
#  'id': '421',
#  'user': '1',
#  'date': datetime.datetime(2020, 5, 19, 8, 47, 38),
#  'date_modified': datetime.datetime(2022, 2, 13, 22, 46, 45),
#  'slug': 'UC2',
#  'post_status': 'publish',
#  'title': 'UC2',
#  'content': '<!-- wp:html -->\n<div align="right">\n<a href="https://twitter.com/openneurosci?ref_src=twsrc%5Etfw" class="twitter-follow-button" data-show-count="false">Follow @openneurosci</a><script async="" src="https://platform.twitter.com/widgets.js" charset="utf-8"></script>\n</div>\n<!-- /wp:html -->\n\n<!-- wp:spacer {"height":45} -->\n<div style="height:45px" aria-hidden="true" class="wp-block-spacer"></div>\n<!-- /wp:spacer -->\n\n<!-- wp:image {"align":"center","id":419,"width":512,"height":116,"sizeSlug":"large","linkDestination":"none"} -->\n<div class="wp-block-image"><figure class="aligncenter size-large is-resized"><img src="https://open-neuroscience-60fc93.ingress-baronn.easywp.com/wp-content/uploads/2022/02/openneuroscience_blue_1600by400_border-1024x232.png" alt="" class="wp-image-419" width="512" height="116"/></figure></div>\n<!-- /wp:image -->\n\n<!-- wp:spacer {"height":45} -->\n<div style="height:45px" aria-hidden="true" class="wp-block-spacer"></div>\n<!-- /wp:spacer -->\n\n<!-- wp:group -->\n<div class="wp-block-group"><!-- wp:heading {"level":3} -->\n<h3 id="summary">Summary</h3>\n<!-- /wp:heading -->\n\n<!-- wp:paragraph {"fontSize":"medium"} -->\n<p class="has-medium-font-size">The open-source optical toolbox UC2 [YouSeeToo] simplifies the process of building optical setups, by combining 3D-printed cubes, each holding a specific component (e.g. lens, mirror) on a magnetic square-grid baseplate. The use of widely available consumables and 3D printing, together with documentation and software, offers an extremely low-cost and accessible alternative for both education and research areas. In order to reduce the entry barrier, we provide a fully comprehensive toolbox called TheBOX. A paper describing the scientific application in detail can be found [here](https://www.biorxiv.org/content/10.1101/2020.03.02.973073v1).</p>\n<!-- /wp:paragraph --></div>\n<!-- /wp:group -->\n\n<!-- wp:spacer {"height":45} -->\n<div style="height:45px" aria-hidden="true" class="wp-block-spacer"></div>\n<!-- /wp:spacer -->\n\n<!-- wp:group -->\n<div class="wp-block-group"><!-- wp:heading {"level":3} -->\n<h3 id="authors">Authors</h3>\n<!-- /wp:heading -->\n\n<!-- wp:paragraph {"fontSize":"medium"} -->\n<p class="has-medium-font-size">Benedict Diederich; René Lachmann; Barbora Marsikova</p>\n<!-- /wp:paragraph --></div>\n<!-- /wp:group -->\n\n<!-- wp:spacer {"height":45} -->\n<div style="height:45px" aria-hidden="true" class="wp-block-spacer"></div>\n<!-- /wp:spacer -->\n\n<!-- wp:group -->\n<div class="wp-block-group"><!-- wp:heading {"level":3} -->\n<h3 id="links">links</h3>\n<!-- /wp:heading -->\n\n<!-- wp:html -->\n<a href="https://useetoo.org">https://useetoo.org</a>\n<!-- /wp:html --></div>\n<!-- /wp:group -->\n\n<!-- wp:spacer {"height":45} -->\n<div style="height:45px" aria-hidden="true" class="wp-block-spacer"></div>\n<!-- /wp:spacer -->\n\n<!-- wp:group -->\n<div class="wp-block-group"><!-- wp:heading {"level":3} -->\n<h3 id="video">video</h3>\n<!-- /wp:heading -->\n\n<!-- wp:embed /--></div>\n<!-- /wp:group -->\n\n<!-- wp:spacer {"height":45} -->\n<div style="height:45px" aria-hidden="true" class="wp-block-spacer"></div>\n<!-- /wp:spacer -->\n\n<!-- wp:group -->\n<div class="wp-block-group"><!-- wp:heading {"level":3} -->\n<h3 id="generated-by">This post was created by:</h3>\n<!-- /wp:heading -->\n\n<!-- wp:paragraph {"fontSize":"medium"} -->\n<p>Andre M Chagas</p>\n<!-- /wp:paragraph --></div>\n<!-- /wp:group --<img src=https://open-neuroscience-60fc93.ingress-baronn.easywp.com/wp-content/uploads/2022/02/openneuroscience_blue_1600by400_border-1024x232.png="false">Follow @openneurosci</a><script async="" src="https://platform.twitter.com/widgets.js" charset="utf-8"></script>\n</div>\n<!-- /wp:html -->\n\n<!-- wp:spacer {"height":45} -->\n<div style="height:45px" aria-hidden="true" class="wp-block-spacer"></div>\n<!-- /wp:spacer -->\n\n<!-- wp:image {"align":"center","id":419,"width":512,"height":116,"sizeSlug":"larg ...
#  'excerpt': '',
#  'link': 'https://open-neuroscience-60fc93.ingress-baronn.easywp.com/project/project-template2/',
#  'comment_status': 'open',
#  'ping_status': 'closed',
#  'terms': [],
#  'custom_fields': [],
#  'password': '',
#  'post_format': 'standard',
#  'thumbnail': [],
#  'sticky': False,
#  'post_type': 'project',
#  'parent_id': '0',
#  'menu_order': 0,
#  'guid': 'https://open-neuroscience-60fc93.ingress-baronn.easywp.com/?post_type=project&#038;p=421',
#  'mime_type': '',
#  'tags': "'Microscopes','Hardware','Software'",
#  'author': 'python-bot'}

# %%
entry
# Out:
#       posted       Marca temporal Dirección de correo electrónico  \
# index
# 1      False  2020-05-06 11:55:08          amgfernandes@gmail.com
#
#       Project Title Project Author  \
# index
# 1      Colaboratory         Google
#
#             Link to Project Website or GitHub repository  \
# index
# 1      https://colab.research.google.com/notebooks/in...
#
#                        Link to raw image of your project  \
# index
# 1      https://www.dropbox.com/s/yoe8nye1by5ed3o/Cola...
#
#       Link to video for your project  \
# index
# 1                                NaN
#
#                               Description of the project       Post Author  \
# index
# 1      Colaboratory is a free Jupyter notebook enviro...  Miguel Fernandes
#
#        ... Project Author Twitter handle  \
# index  ...
# 1      ...                           NaN
#
#       Do you consider yourself part of an underrepresented group in science?  \
# index
# 1                                                    NaN
#
#       If you do consider yourself part of an underrepresented group in science, would you mind telling us which one?  \
# index
# 1                                                    NaN
#
#       Project location (city, country) Post Author Twitter handle  \
# index
# 1                                  NaN                        NaN
#
#       Would you like to showcase this project on our Seminar Series? ...20  \
# index
# 1                                                    NaN               NaN
#
#       lkjdsf Project categories (please select at most one per row) [categ]  \
# index
# 1        NaN                                                NaN
#
#                              tags
# index
# 1      'Software','Data Analysis'
#
# [1 rows x 24 columns]
